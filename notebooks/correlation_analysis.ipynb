# %% [markdown]
# # **Import Modules and Libraries**

# %% [markdown]
# ## *Python*

# %%
import pandas as pd
import os
import sys

# %% [markdown]
# ## *Custom*

# %%
#import customised modules

#define path
sys.path.append(os.path.abspath(os.path.join('..')))

##import correlation analyser modules
from script.correlation_analyser import load_stock_data
from script.correlation_analyser import save_dataframe
from script.correlation_analyser import process_and_align_data
from script.correlation_analyser import analyse_and_plot

# %% [markdown]
# # **Load Data**

# %%
#load necessary data

#--------------AAPL--------------#
AAPL_hist = pd.read_csv('C:/Users/nuhamin/Documents/kifiya/week 1/' \
                    'Stock-Market-Price-Prediction-with-Sentiment-Analysis/' \
                        'data/price_data/AAPL_hist_data.csv')
AAPL_senti= pd.read_csv('C:/Users/nuhamin/Documents/kifiya/week 1/' \
                        'Stock-Market-Price-Prediction-with-Sentiment-Analysis/' \
                            'data/sentiment_data/AAPL_sentiment_data.csv')

#--------------AMZN--------------#
AMZN_hist = pd.read_csv('C:/Users/nuhamin/Documents/kifiya/week 1/' \
                    'Stock-Market-Price-Prediction-with-Sentiment-Analysis/' \
                        'data/price_data/AMZN_hist_data.csv')
AMZN_senti= pd.read_csv('C:/Users/nuhamin/Documents/kifiya/week 1/' \
                        'Stock-Market-Price-Prediction-with-Sentiment-Analysis/' \
                            'data/sentiment_data/AMZN_sentiment_data.csv')

#--------------GOOG--------------#
GOOG_hist = pd.read_csv('C:/Users/nuhamin/Documents/kifiya/week 1/' \
                    'Stock-Market-Price-Prediction-with-Sentiment-Analysis/' \
                        'data/price_data/GOOG_hist_data.csv')
GOOG_senti= pd.read_csv('C:/Users/nuhamin/Documents/kifiya/week 1/' \
                        'Stock-Market-Price-Prediction-with-Sentiment-Analysis/' \
                            'data/sentiment_data/GOOG_sentiment_data.csv')

#--------------META--------------#
META_hist = pd.read_csv('C:/Users/nuhamin/Documents/kifiya/week 1/' \
                    'Stock-Market-Price-Prediction-with-Sentiment-Analysis/' \
                        'data/price_data/META_hist_data.csv')
META_senti= pd.read_csv('C:/Users/nuhamin/Documents/kifiya/week 1/' \
                        'Stock-Market-Price-Prediction-with-Sentiment-Analysis/' \
                            'data/sentiment_data/META_sentiment_data.csv')

#--------------MSFT--------------#
MSFT_hist = pd.read_csv('C:/Users/nuhamin/Documents/kifiya/week 1/' \
                    'Stock-Market-Price-Prediction-with-Sentiment-Analysis/' \
                        'data/price_data/MSFT_hist_data.csv')
MSFT_senti= pd.read_csv('C:/Users/nuhamin/Documents/kifiya/week 1/' \
                        'Stock-Market-Price-Prediction-with-Sentiment-Analysis/' \
                            'data/sentiment_data/MSFT_sentiment_data.csv')

#--------------NVDA--------------#
NVDA_hist = pd.read_csv('C:/Users/nuhamin/Documents/kifiya/week 1/' \
                    'Stock-Market-Price-Prediction-with-Sentiment-Analysis/' \
                        'data/price_data/NVDA_hist_data.csv')
NVDA_senti= pd.read_csv('C:/Users/nuhamin/Documents/kifiya/week 1/' \
                        'Stock-Market-Price-Prediction-with-Sentiment-Analysis/' \
                            'data/sentiment_data/NVDA_sentiment_data.csv')

#--------------TSLA--------------#
TSLA_hist = pd.read_csv('C:/Users/nuhamin/Documents/kifiya/week 1/' \
                    'Stock-Market-Price-Prediction-with-Sentiment-Analysis/' \
                        'data/price_data/TSLA_hist_data.csv')
TSLA_senti= pd.read_csv('C:/Users/nuhamin/Documents/kifiya/week 1/' \
                        'Stock-Market-Price-Prediction-with-Sentiment-Analysis/' \
                            'data/sentiment_data/TSLA_sentiment_data.csv')

# %%
#select plot directory and plot name to save plot
plot_folder = 'C:/Users/nuhamin/Documents/kifiya/week 1/' \
'Stock-Market-Price-Prediction-with-Sentiment-Analysis/' \
'plot images/correlation_plot'

#select plot directory and plot name to save plot
df_folder= 'C:/Users/nuhamin/Documents/kifiya/week 1/' \
'Stock-Market-Price-Prediction-with-Sentiment-Analysis/' \
'data/correlation_data'

# %% [markdown]
# # **AAPL**

# %%
ticker = 'AAPL'
aligned_data=process_and_align_data(AAPL_hist, AAPL_senti, start_date='2020-03-09', end_date='2020-06-10')
print(aligned_data.head())
save_dataframe(ticker, aligned_data, df_folder, df_name=f'{ticker}_correlation_data')
analyse_and_plot(ticker,AAPL_hist, AAPL_senti, start_date='2020-03-09', end_date='2020-06-10',plot_folder=plot_folder)
# Out:
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2020-03-09  65.937500  69.522499  65.750000  66.542503  64.736046
# 1 2020-03-10  69.285004  71.610001  67.342499  71.334999  69.398438
# 2 2020-03-11  69.347504  70.305000  67.964996  68.857498  66.988190
# 3 2020-03-12  63.985001  67.500000  62.000000  62.057499  60.372791
# 4 2020-03-13  66.222504  69.980003  63.237499  69.492500  67.605965
#
#       Volume     SMA_15     SMA_60     RSI_15     RSI_60      MACD  \
# 0  286744800  69.719479  73.680566  32.785447  36.747258 -2.061255
# 1  285290000  69.652838  73.240229  44.686508  44.398565 -2.029117
# 2  255598800  69.234026  72.702972  40.561310  41.656560 -2.173085
# 3  418474000  68.618938  71.742645  31.650764  35.349168 -2.788839
# 4  370732000  68.731060  71.172311  46.049338  44.943667 -2.662481
#
#    MACD_Signal  MACD_Diff  Volatility  Sentiment Sentiment_Category  \
# 0    -1.399061  -0.662194    3.688743  -0.155556           Negative
# ...

# %% [markdown]
# # **AMZN**

# %%
ticker = 'AMZN'
aligned_data=process_and_align_data(AMZN_hist, AMZN_senti, start_date='2020-04-27', end_date='2020-06-10')
print(aligned_data.head())
save_dataframe(ticker, aligned_data, df_folder, df_name=f'{ticker}_correlation_data')
analyse_and_plot(ticker,AMZN_hist, AMZN_senti, start_date='2020-04-27', end_date='2020-06-10',plot_folder=plot_folder)
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2020-04-27  122.160004  122.244003  118.150002  118.800003  118.800003
# 1 2020-04-28  118.605003  118.675003  115.300003  115.704002  115.704002
# 2 2020-04-29  116.500504  119.594498  115.500000  118.635498  118.635498
# 3 2020-04-30  120.991997  123.750000  119.800499  123.699997  123.699997
# 4 2020-05-01  116.839996  118.122002  112.909500  114.302002  114.302002
#
#       Volume      SMA_15      SMA_60     RSI_15     RSI_60      MACD  \
# 0  112912000  118.225401  108.889225  68.088850  64.717005  6.284371
# 1  105388000  118.379201  109.764550  58.993311  60.482703  5.861140
# 2   91832000  118.704350  110.822025  64.046233  62.901944  5.696606
# 3  190692000  119.033400  112.237775  70.923740  66.618352  5.906786
# 4  195452000  118.588600  113.155800  50.863069  55.715851  5.254444
#
#    MACD_Signal  MACD_Diff  Volatility  Sentiment Sentiment_Category  \
# ...

# %% [markdown]
# # **GOOG**

# %%
ticker = 'GOOG'
aligned_data=process_and_align_data(GOOG_hist, GOOG_senti, start_date='2018-11-13', end_date='2020-06-10')
print(aligned_data.head())
save_dataframe(ticker, aligned_data, df_folder, df_name=f'{ticker}_correlation_data')
analyse_and_plot(ticker,GOOG_hist, GOOG_senti, start_date='2018-11-13', end_date='2020-06-10',plot_folder=plot_folder)
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume  \
# 0 2018-11-13  52.164501  52.830250  51.557499  51.802502  51.743618  30274000
# 1 2018-11-14  52.500000  52.728199  51.549999  52.182999  52.123684  31318000
# 2 2018-11-15  52.235500  53.592499  51.589001  53.235500  53.174988  36722000
# 3 2018-11-16  52.970501  53.349998  52.449001  53.074501  53.014172  33162000
# 4 2018-11-19  52.860001  53.039501  50.813000  51.000000  50.942032  37172000
#
#       SMA_15     SMA_60     RSI_15     RSI_60      MACD  MACD_Signal  \
# 0  53.025060  53.429425  39.776384  40.792055 -1.071210    -1.147098
# 1  52.859698  53.249554  42.254506  42.043146 -1.064307    -1.130539
# 2  52.833278  53.191471  48.737590  45.402308 -0.962904    -1.097012
# 3  52.851756  53.104145  47.824996  44.982503 -0.885313    -1.054672
# 4  52.751421  52.901476  37.714571  39.969846 -0.979732    -1.039684
#
#    MACD_Diff  Volatility  Sentiment Sentiment_Category  Daily_Return
# ...

# %% [markdown]
# # **META**

# %%
ticker = 'META'
aligned_data=process_and_align_data(META_hist, META_senti, start_date='2020-02-19', end_date='2020-06-10')
print(aligned_data.head())
save_dataframe(ticker, aligned_data, df_folder, df_name=f'{ticker}_correlation_data')
analyse_and_plot(ticker,META_hist, META_senti, start_date='2020-02-19', end_date='2020-06-10',plot_folder=plot_folder)
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2020-02-20  216.520004  218.770004  212.949997  214.580002  214.139954
# 1 2020-02-21  213.479996  214.240005  208.830002  210.179993  209.748962
# 2 2020-02-24  201.800003  203.649994  198.169998  200.720001  200.308380
# 3 2020-02-25  202.250000  203.500000  195.949997  196.770004  196.366486
# 4 2020-02-26  197.190002  201.210007  195.490005  197.199997  196.795593
#
#      Volume      SMA_15      SMA_60     RSI_15     RSI_60      MACD  \
# 0  13109200  212.700914  212.590141  51.929395  51.358519  0.169337
# 1  14092300  212.634048  212.112123  43.832994  46.598494 -0.131026
# 2  23080100  211.475429  211.252888  31.937682  38.518981 -1.117955
# 3  21433500  209.849771  210.349744  28.366264  35.791419 -2.192903
# 4  16524500  208.852818  209.322356  29.322222  36.308221 -2.975877
#
#    MACD_Signal  MACD_Diff  Volatility  Sentiment Sentiment_Category  \
# ...

# %% [markdown]
# # **MSFT**

# %%
ticker = 'MSFT'
aligned_data=process_and_align_data(MSFT_hist, MSFT_senti, start_date='2010-04-06', end_date='2019-10-21')
print(aligned_data.head())
save_dataframe(ticker, aligned_data, df_folder, df_name=f'{ticker}_correlation_data')
analyse_and_plot(ticker,MSFT_hist, MSFT_senti, start_date='2010-04-06', end_date='2019-10-21',plot_folder=plot_folder)
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2010-04-06   29.150000   29.580000   28.980000   29.320000   22.221144
# 1 2016-06-30   50.720001   51.299999   50.500000   51.169998   45.869160
# 2 2017-06-09   72.040001   72.080002   68.589996   70.320000   64.612137
# 3 2018-01-29   95.139999   95.449997   93.720001   93.919998   87.191978
# 4 2018-08-16  108.300003  108.860001  107.300003  107.639999  101.221771
#
#      Volume      SMA_15      SMA_60     RSI_15     RSI_60      MACD  \
# 0  47366800   22.403040   22.316262  48.554088  50.272529  0.088107
# 1  28527800   45.152045   45.488647  53.887585  50.263397 -0.292226
# 2  49187400   65.377500   64.105392  50.893340  56.697489  1.035606
# 3  31569900   84.873857   83.059369  82.195355  75.323841  1.931421
# 4  21384300  101.836858  101.285172  52.641363  55.747170  1.257852
#
#    MACD_Signal  MACD_Diff  Volatility  Sentiment Sentiment_Category  \
# ...

# %% [markdown]
# # **NVDA**

# %%
ticker = 'NVDA'
aligned_data=process_and_align_data(NVDA_hist, NVDA_senti, start_date='2011-03-03', end_date='2020-06-10')
print(aligned_data.head())
save_dataframe(ticker, aligned_data, df_folder, df_name=f'{ticker}_correlation_data')
analyse_and_plot(ticker,NVDA_hist, NVDA_senti, start_date='2011-03-03', end_date='2020-06-10',plot_folder=plot_folder)
# Out:
#         Date     Open     High      Low    Close  Adj Close      Volume  \
# 0 2011-03-03  0.53075  0.53375  0.50600  0.52175   0.478563  1593704000
# 1 2011-03-07  0.52275  0.52450  0.49875  0.51175   0.469391  1019140000
# 2 2011-03-08  0.51725  0.52000  0.47800  0.48875   0.448295  1947184000
# 3 2011-03-09  0.48725  0.49200  0.47425  0.47850   0.438893  1318976000
# 4 2011-03-10  0.46750  0.47100  0.44750  0.44800   0.410918  1722736000
#
#      SMA_15    SMA_60     RSI_15     RSI_60      MACD  MACD_Signal  MACD_Diff  \
# 0  0.523576  0.534502  36.537855  45.150371 -0.004420     0.007066  -0.011485
# 1  0.500462  0.523565  34.354220  43.742500 -0.009751     0.001427  -0.011177
# 2  0.492069  0.517775  29.691338  40.632290 -0.013354    -0.001530  -0.011825
# 3  0.485259  0.512351  27.821500  39.320752 -0.016776    -0.004579  -0.012197
# 4  0.474413  0.506195  23.026937  35.710346 -0.021496    -0.007962  -0.013534
#
#    Volatility  Sentiment Sentiment_Category  Daily_Return
# ...

# %% [markdown]
# # **TSLA**

# %%
ticker = 'TSLA'
aligned_data=process_and_align_data(TSLA_hist, TSLA_senti, start_date='2019-07-01', end_date='2020-06-10')
print(aligned_data.head())
save_dataframe(ticker, aligned_data, df_folder, df_name=f'{ticker}_correlation_data')
analyse_and_plot(ticker,TSLA_hist, TSLA_senti, start_date='2019-07-01', end_date='2020-06-10',plot_folder=plot_folder)
# Out:
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2019-07-01  15.347333  15.540000  15.085333  15.144667  15.144667
# 1 2019-07-02  15.259333  15.276667  14.814667  14.970000  14.970000
# 2 2019-07-03  15.959333  16.104668  15.634000  15.660000  15.660000
# 3 2019-07-05  15.638000  15.696667  15.386667  15.540000  15.540000
# 4 2019-07-08  15.416000  15.483333  15.244000  15.356000  15.356000
#
#       Volume     SMA_15     SMA_60     RSI_15     RSI_60      MACD  \
# 0  123201000  14.858600  14.408433  63.176739  53.075939  0.140083
# 1  138885000  14.857333  14.511600  58.479002  51.461509  0.150365
# 2  213016500  14.913800  14.639300  68.696088  56.911534  0.211750
# 3  105985500  15.003667  14.729800  65.577873  55.765270  0.247858
# 4   88207500  15.060200  14.815933  60.870532  54.009500  0.258645
#
#    MACD_Signal  MACD_Diff  Volatility  Sentiment Sentiment_Category  \
# 0     0.005527   0.134556    0.553385   0.079167           Positive
# ...
